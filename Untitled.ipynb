# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"data/2014data_split.csv")

# %% [markdown]
# 去除多余列

# %%
data.drop(data.columns[3],axis=1,inplace=True)

# %% [markdown]
# 将编号列作为索引

# %%
data.set_index('编号', inplace = True)

# %%
data.replace({'强烈反对': -2, '反对':- 1, '同意':1, '强烈同意':2}, inplace = True)

# %%
data.head()
# Out:
#             日期        时间  如果人民没有受过民主教育，他们是不应该拥有普选权的。  人权高于主权。  \
# 编号
# 1   2014-01-01  07:23:41                           1        1
# 2   2014-01-01  07:25:14                          -1       -1
# 3   2014-01-01  07:24:57                          -1        1
# 4   2014-01-01  07:34:49                           1        1
# 5   2014-01-01  07:41:20                          -1        1
#
#     发生重大社会安全事件时，即使认为信息公开会导致骚乱的风险，政府仍应该开放信息传播。  西方的多党制不适合中国国情。  \
# 编号
# 1                                           1               1
# 2                                          -2               1
# 3                                           2              -1
# 4                                          -1              -1
# 5                                          -1              -1
#
#     在中国照搬西方式的言论自由会导致社会失序。  由高校自主考试招生比全国统一考试招生更好。  应该容许宗教人士在非宗教场所公开传教。  \
# 编号
# 1                       1                     -1                   -1
# 2                       1                     -1                    1
# 3                      -1                      1                   -1
# 4                       1                     -1                   -1
# 5                       1                      1                    1
#
#     无论中小学生或大学生，都应参加由国家统一安排的军训。   ...    即使有人口压力，国家和社会也无权干涉个人要不要孩子，要几个孩子。  \
# 编号                               ...
# 1                           -1   ...                                  -1
# 2                           -1   ...                                  -1
# 3                           -1   ...                                   1
# 4                           -1   ...                                  -1
# 5                            1   ...                                  -1
#
#     周易八卦能够有效的解释很多事情。  中国传统医学对人体健康的观念比现代主流医学更高明。  汉字无需人为推行简化。  \
# 编号
# 1                  1                          1            1
# 2                  1                          1           -1
# 3                 -1                         -1           -1
# 4                  1                          1            1
# 5                  1                         -1            1
#
#     应当将中国传统文化的经典作品作为儿童基础教育读物。  如果是出于自愿，我会认可我的孩子和同性结成伴侣关系。  性别  出生年份       年收入  \
# 编号
# 1                           1                           1   F  1993     0-25k
# 2                          -1                          -1   M  1991     300k+
# 3                           1                           1   M  1992   25k-50k
# 4                           1                          -1   M  1992  75k-100k
# 5                           1                           1   M  1992  75k-100k
#
#         学历
# 编号
# 1       大学
# 2       大学
# 3       大学
# 4   研究生及以上
# 5   研究生及以上
#
# [5 rows x 56 columns]

# %%
data.to_csv(r"data/2014data_splite_replaced.csv", encoding='utf-8')
