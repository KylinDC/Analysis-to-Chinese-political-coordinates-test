# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"data/2014data_split.csv")

# %% [markdown]
# 去除多余列

# %%
data.drop(data.columns[3],axis=1,inplace=True)

# %% [markdown]
# 将编号列作为索引

# %%
data.set_index('编号', inplace = True)

# %%
data.replace({'强烈反对': -2, '反对':- 1, '同意':1, '强烈同意':2}, inplace = True)

# %%
data.head()
# Out:
#             日期        时间  如果人民没有受过民主教育，他们是不应该拥有普选权的。  人权高于主权。  \
# 编号
# 1   2014-01-01  07:23:41                           1        1
# 2   2014-01-01  07:25:14                          -1       -1
# 3   2014-01-01  07:24:57                          -1        1
# 4   2014-01-01  07:34:49                           1        1
# 5   2014-01-01  07:41:20                          -1        1
#
#     发生重大社会安全事件时，即使认为信息公开会导致骚乱的风险，政府仍应该开放信息传播。  西方的多党制不适合中国国情。  \
# 编号
# 1                                           1               1
# 2                                          -2               1
# 3                                           2              -1
# 4                                          -1              -1
# 5                                          -1              -1
#
#     在中国照搬西方式的言论自由会导致社会失序。  由高校自主考试招生比全国统一考试招生更好。  应该容许宗教人士在非宗教场所公开传教。  \
# 编号
# 1                       1                     -1                   -1
# 2                       1                     -1                    1
# 3                      -1                      1                   -1
# 4                       1                     -1                   -1
# 5                       1                      1                    1
#
#     无论中小学生或大学生，都应参加由国家统一安排的军训。   ...    即使有人口压力，国家和社会也无权干涉个人要不要孩子，要几个孩子。  \
# 编号                               ...
# 1                           -1   ...                                  -1
# 2                           -1   ...                                  -1
# 3                           -1   ...                                   1
# 4                           -1   ...                                  -1
# 5                            1   ...                                  -1
#
#     周易八卦能够有效的解释很多事情。  中国传统医学对人体健康的观念比现代主流医学更高明。  汉字无需人为推行简化。  \
# 编号
# 1                  1                          1            1
# 2                  1                          1           -1
# 3                 -1                         -1           -1
# 4                  1                          1            1
# 5                  1                         -1            1
#
#     应当将中国传统文化的经典作品作为儿童基础教育读物。  如果是出于自愿，我会认可我的孩子和同性结成伴侣关系。  性别  出生年份       年收入  \
# 编号
# 1                           1                           1   F  1993     0-25k
# 2                          -1                          -1   M  1991     300k+
# 3                           1                           1   M  1992   25k-50k
# 4                           1                          -1   M  1992  75k-100k
# 5                           1                           1   M  1992  75k-100k
#
#         学历
# 编号
# 1       大学
# 2       大学
# 3       大学
# 4   研究生及以上
# 5   研究生及以上
#
# [5 rows x 56 columns]

# %%
data.corrwith(data[[-3]])
# Out:
# 不应公开谈论自己长辈的缺点。                               NaN
# 与其让国有企业亏损破产，不如转卖给资本家。                        NaN
# 两个成年人之间自愿的性行为是其自由，无论其婚姻关系为何。                 NaN
# 中国传统医学对人体健康的观念比现代主流医学更高明。                    NaN
# 中国改革开放以来的经济发展的成果都被一小群人占有了，大多数人没得到什么好处。       NaN
# 人权高于主权。                                      NaN
# 以美国为首的西方国家不可能真正容许中国崛起成为一流强国。                 NaN
# 出生年份                                         1.0
# 判断艺术作品的价值的根本标准是看是不是受到人民大众喜爱。                 NaN
# 即使有人口压力，国家和社会也无权干涉个人要不要孩子，要几个孩子。             NaN
# 发生重大社会安全事件时，即使认为信息公开会导致骚乱的风险，政府仍应该开放信息传播。    NaN
# 周易八卦能够有效的解释很多事情。                             NaN
# 哪怕经历了违反程序规定的审讯和取证过程，确实有罪的罪犯也应被处刑。            NaN
# 国家应当采取措施培养和支持体育健儿在各种国际比赛场合为国争光。              NaN
# 国家有义务进行对外援助。                                 NaN
# 国家的统一和领土完整是社会的最高利益。                          NaN
# 国家领导人及开国领袖的形象可以作为文艺作品的丑化对象。                  NaN
# 国有企业的利益属于国家利益。                               NaN
# 在中国照搬西方式的言论自由会导致社会失序。                        NaN
# 在华外国资本应享受和民族资本同样的待遇。                         NaN
# 在重大工程项目的决策中，个人利益应该为社会利益让路。                   NaN
# 如果人民没有受过民主教育，他们是不应该拥有普选权的。                   NaN
# 如果国家综合实力许可，那么中国有权为了维护自己的利益而采取任何行动。           NaN
# 如果是出于自愿，我会认可我的孩子和同性结成伴侣关系。                   NaN
# 如果猪肉价格过高，政府应当干预。                             NaN
# 市场竞争中自然形成的垄断地位是无害的。                          NaN
# 应当允许媒体代表某一特定阶层或利益集团发言。                       NaN
# 应当对国外同类产品征收高额关税来保护国内民族工业。                    NaN
# 应当将中国传统文化的经典作品作为儿童基础教育读物。                    NaN
# 应该允许中国公民同时具有外国国籍。                            NaN
# 应该容许宗教人士在非宗教场所公开传教。                          NaN
# 当法律未能充分制止罪恶行为时，人民群众有权自发对罪恶行为进行制裁。            NaN
# 律师即使明知被辩护人的犯罪事实也应当尽力为其进行辩护。                  NaN
# 改善低收入者生活的首要手段是国家给予财政补贴和扶持。                   NaN
# 政府应当采用较高的粮食收购价格以增加农民收入。                      NaN
# 教育应当尽可能公立。                                   NaN
# 无论中小学生或大学生，都应参加由国家统一安排的军训。                   NaN
# 最低工资应由国家规定。                                  NaN
# 有钱人理应获得更好的医疗服务。                              NaN
# 条件允许的话应该武力统一台湾。                              NaN
# 汉字无需人为推行简化。                                  NaN
# 浪费粮食也是个人的自由。                                 NaN
# 现代中国社会需要儒家思想。                                NaN
# 由高校自主考试招生比全国统一考试招生更好。                        NaN
# 私人应当可以拥有和买卖土地。                               NaN
# 西方的多党制不适合中国国情。                               NaN
# 试图控制房地产价格的行为会破坏经济发展。                         NaN
# 资本积累的过程总是伴随着对普通劳动人民利益的伤害。                    NaN
# 那些关系到国家安全、以及其他重要国计民生的领域，必须全部由国有企业掌控。         NaN
# 靠运作资金赚钱的人对社会的贡献比不上靠劳动赚钱的人。                   NaN
# 高收入者应该公开自己的经济来源。                             NaN
# dtype: float64
